# %% [markdown]
# ### **The data were obtained in a survey of students math and portuguese language courses in secondary school. It contains a lot of interesting social, gender and study information about students. You can use it for some EDA or try to predict students final grade.**
#
# Content:
#
# Attributes for both student-mat.csv (Math course) and student-por.csv (Portuguese language course) datasets:
#
# - 1. **school** - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# - 2. **sex** - student's sex (binary: 'F' - female or 'M' - male)
# - 3. **age** - student's age (numeric: from 15 to 22)
# - 4. **address** - student's home address type (binary: 'U' - urban or 'R' - rural)
# - 5. **famsize** - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# - 6. **Pstatus** - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# - 7. **Medu** - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# - 8. **Fedu** - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# - 9. **Mjob** - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - 10. **Fjob** - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# - 11. **reason** - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# - 12. **guardian** - student's guardian (nominal: 'mother', 'father' or 'other')
# - 13. **traveltime** - home to school travel time (numeric: 1 - 1 hour)
# - 14. **studytime** - weekly study time (numeric: 1 - 10 hours)
# - 15. **failures** - number of past class failures (numeric: n if 1<=n<3, else 4)
# - 16. **schoolsup** - extra educational support (binary: yes or no)
# - 17. **famsup** - family educational support (binary: yes or no)
# - 18. **paid** - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# - 19. **activities** - extra-curricular activities (binary: yes or no)
# - 20. **nursery** - attended nursery school (binary: yes or no)
# - 21. **higher** - wants to take higher education (binary: yes or no)
# - 22. **internet** - Internet access at home (binary: yes or no)
# - 23. **romantic** - with a romantic relationship (binary: yes or no)
# - 24. **famrel** - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# - 25. **freetime** - free time after school (numeric: from 1 - very low to 5 - very high)
# - 26. **goout** - going out with friends (numeric: from 1 - very low to 5 - very high)
# - 27. **Dalc** - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - 28. **Walc** - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# - 29. **health** - current health status (numeric: from 1 - very bad to 5 - very good)
# - 30. **absences** - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# - 31. **G1** - first period grade (numeric: from 0 to 20)
# - 32. **G2** - second period grade (numeric: from 0 to 20)
# - 33. **G3** - final grade (numeric: from 0 to 20, output target)
#
# Additional note: there are several (382) students that belong to both datasets .
# These students can be identified by searching for identical attributes
# that characterize each student, as shown in the annexed R file.
# Source Information
#
# P. Cortez and A. Silva. Using Data Mining to Predict Secondary School Student Performance. In A. Brito and J. Teixeira Eds., Proceedings of 5th FUture BUsiness TEChnology Conference (FUBUTEC 2008) pp. 5-12, Porto, Portugal, April, 2008, EUROSIS, ISBN 978-9077381-39-7.
#
# Fabio Pagnotta, Hossain Mohammad Amran.
# Email:fabio.pagnotta@studenti.unicam.it, mohammadamra.hossain '@' studenti.unicam.it
# University Of Camerino
#
# https://archive.ics.uci.edu/ml/datasets/STUDENT+ALCOHOL+CONSUMPTION
# ____

# %% [markdown]
# # ***Objective***
# - **The objective of the project is to create machine learning models for predicting Mathematics score(G3) and Portuguese score(G3) of portuguese students who have certain social factors by using adjusted accuracy score and confusion matrix as tools to measure performance of the models.**
# ___

# %% [markdown]
# # ***Code Description:***
# 1. **Load Data**
#     - 1.1 load math data
#     - 1.2 load porguese data
# 2. **Explore Data for both Mathematics and Portuguese data**
#     - 2.1 Data size
#         - Math data (395, 33)
#         - Portuguese data (649, 33)
#     - 2.2 Missing Values/Data Imputation
#         - No Missing values for Math data, therefore no data imputation is needed
#         - No Missing values for Portuguese data, therefore no data imputation is needed
#     - 2.3 Data Duplicated
#         - No duplicated data for Math data
#         - No duplicated data for Portuguese data
#     - 2.4 Check Spelling Mistakes Data
#         - Threre is completely no spelling mistake in both Math and Portugeuse data. By checking mistake spelling data, it will ensure that we have correct label-encoded data.
#     - 2.4 Univariate Outlier detection by using these tools
#         - 1. scatter
#         - 2. boxplot
#         - 3. z-score
#         - After applying these tools, we decided to drop data that have z-score of G3 less than -2.2 because we scrutinize that students who have G3 score equal to 0 (z-score < -2.2) were never absent from the class. Therefore, the score of G3 should not be equal to zero. Hence, we assumed that these data were collected inaccurately.
#         - Eliminate 38 samples (approximately 10%) for math dataframe
#         - Eliminate 19 samples (approximately 3%) for porgutuese dataframe
#     - 2.5 Explore data: relationship amongs independence variables vs dependent variables
#         - G3 be the only dependent variable on both Math and Portuguese
#         - 1. G3 Math and independent variables
#         - 2. G3 Portuguese and independent variables
#         - 3. G3 Math and G3 Portuguese Distribution
#         - 4. G3 Score and School
#         - 5. Gender and G3 Score on both Math and Portuguese
#         - 6. Internet and G3 Score on both Math and Portuguese
#         - 7. Family support on education and G3 Score on both Math and Portuguese
#         - 8. Father Occupations and G3 Score on both Math and Portuguese
#         - 9. Mother Occupations and G3 Score on both Math and Portuguese
#         - 10. Study time and G3 Score on both Math and Portuguese
#         - 11. Workday Alcohol Consumption and G3 Score on both Math and Portuguese
#         - 12. Weekend Alcohol Consumption and G3 Score on both Math and Portuguese
# 3. **Preprocessing Data (Starts with Math data)**
#     - 3.1 Create function for encoding data and normalize data
#         - Encoding data for nominal data
#         - Standard Normalization for numeric data
#     - 3.2 Apply encoding function and normalize data
#     - 3.3 Checking Datatype of each columns before modeling
#     - 3.4 Re-check correlation between G3(target) and features
# 4. **Model Building (for math data)**
#     - 4.1 Seperate data for traning.
#         - There are 357 samples in math dataframe
#         - 57 samples (almost 20%) for test set
#         - 300 samples for training and 10 folds cross validation
#     - 4.2 Modeling Building by each algorithms
#         - 1.) Decision Tree
#         - 2.) RandomForestClassifier
#         - 3.) Support Vector Machine
#         - 4.) GaussianNB
#         - The mean accuracy score offered by each model are very low, approximately 10%. Nonetheless, if we subtly consider the predicted value and true value, we can clearly see that predicted values only slightly differ from true value. Therefore, it is reasonable to create a new metric that loosely measure the prediction accuracy. To elaborate, this metric is going to give the score to a model that offers predicted value differed from true value by 2 unit as correct prediction and this metrics is called adjusted accuracy score. For example, true value = 7, predicted value = 9 -> correct prediction
#     - 4.3 Select model and test with unseen data
#         - By considering models' performance (adjusted accuracy score) from running cross validation, support vector machine model and random forest classifier models tend to offer the most promising result because these two model provide highest accuracy levels. Both Random Forest Classifier and Support Vector Machine provide accuracy at similar levels arround 50-60%. Therefore, we do not finalize which model to be used yet. We will take these two models to test with unseen data and tuning first and then select the model later on.
# 5. **Model Evaluation**
#     - 5.1 Test SVC model with unseen data
#     - 5.2 Test RandomForest model with unseen data
#     - Metrics: Accuracy Score, Confusion Matrix, Classification Report
#     - Both models still provide accuracy at the same levels
# 6. **Model Improvement**
#     - 6.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model
#         - Re-train SVC model and evaluate performance - name: model_svc_math
#     - 6.2.1 Optimize model by changing hyperparameter and measure the performance via visualization.
#         - Re-train randomforest model and evaluate - name: model_RNF1_math
#     - 6.2.2 RandomoizeSearchCV for tuning the model
#         - Re-train randomforest model and evaluate - name: model_RNF2_math
# 7. **Re-create a model for prediction Portuguese score (most of the processes are similar with creating model for predicting mathematics score, following Step 3-6)**
#      - 7.1 Preprocess Portuguese data
#         - 7.1.1 Apply labelEncode function and standardScaler function and drop irrelavant columns for Portuguese data
#         - 7.1.2 Rearrange Columns
#         - 7.1.3 Re-check correlation between G3(target) and features
#      - 7.2 Model building
#         - There are only 633 samples. Therefore, K-Fold cross validation is needed
#         - 133 samples (approximately 20%) for test set
#         - 500 samples for training and 10 folds cross validation
#
#         - 7.2.1 Modeling Building by each algorithms
#             - 1.) Decision Tree
#             - 2.) RandomForestClassifier
#             - 3.) Support Vector Machine
#             - 4.) GaussianNB
#         - 7.2.2 Select model and test with unseen data
#      - 7.3 Model Evaluation
#         - Testing with unseen data
#         - Metrics: Accuracy Score, Confusion Matrix, Classification Report
#         - 7.3.1 Test SVC model with unseen data - Portuguese
#         - 7.3.2 Test Random Forest model with unseen data - Portuguese
#      - 7.4 Model Improvement
#         - 7.4.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model
#             - Re-train SVC model and evaluate performance - name: model_svc_por
#         - 7.4.2 RandomoizeSearchCV for tuning the model
#             - Re-train randomforest model and evaluate - name: model_RNF_por
# 8. **Conclusion**
#      - Select the model for math score prediction
#      - Select the model for protuguese score prediction
# 9. **Deployment**
#  ___

# %% [markdown]
# # 1) Load Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
import warnings
warnings.simplefilter(action='ignore')
math = pd.read_csv('student-mat.csv')
por = pd.read_csv('student-por.csv')

# %%
math.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
por.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        4   0  11  11
# 1      5        3      3     1     1      3        2   9  11  11
# 2      4        3      2     2     3      3        6  12  13  12
# 3      3        2      2     1     1      5        0  14  14  14
# 4      4        3      2     1     2      5        0  11  13  13
#
# [5 rows x 33 columns]

# %% [markdown]
# ___

# %% [markdown]
# # 2) Explore Data

# %% [markdown]
# ## 2.1 Data size

# %%
print('Math data',math.shape)
print('Portuguese data',por.shape)
# Out:
# Math data (395, 33)
# Portuguese data (649, 33)

# %%
math.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
math.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
por.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# ...

# %%
math.corr()['G3']
# Out:
# age          -0.161579
# Medu          0.217147
# Fedu          0.152457
# traveltime   -0.117142
# studytime     0.097820
# failures     -0.360415
# famrel        0.051363
# freetime      0.011307
# goout        -0.132791
# Dalc         -0.054660
# Walc         -0.051939
# health       -0.061335
# absences      0.034247
# G1            0.801468
# G2            0.904868
# G3            1.000000
# Name: G3, dtype: float64

# %%
por.corr()['G3']
# Out:
# age          -0.106505
# Medu          0.240151
# Fedu          0.211800
# traveltime   -0.127173
# studytime     0.249789
# failures     -0.393316
# famrel        0.063361
# freetime     -0.122705
# goout        -0.087641
# Dalc         -0.204719
# Walc         -0.176619
# health       -0.098851
# absences     -0.091379
# G1            0.826387
# G2            0.918548
# G3            1.000000
# Name: G3, dtype: float64

# %% [markdown]
# ## 2.2 Missing Data

# %%
print('Missing Data Math:')
print(math.isnull().sum())
print('-----------')
print('Missing Data Portuguese:')
print(por.isnull().sum())
# Out:
# Missing Data Math:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64
# -----------
# Missing Data Portuguese:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# ...

# %% [markdown]
# - No missing data on both Math and Portuguese dataframe

# %% [markdown]
# ## 2.3 Data Duplicated

# %%
math[math.duplicated()]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %%
por[por.duplicated()]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3]
# Index: []
#
# [0 rows x 33 columns]

# %% [markdown]
# - No duplicated data for each dataframe
# - However, there are several (382) students that belong to both datasets. These students can be identified by searching for identical attributes
# - ["school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"]
# - find here are those students who take both math and portuguese.

# %% [markdown]
# ## 2.4 Check Spelling Mistakes

# %% [markdown]
# ## note.  ****************
# - แบ่งประเภทข้อมูล เพื่อนำไปใช้งานต่อ ex. norminal - getdummy

# %%
norminal = ['school','sex','address','famsize','Pstatus','Mjob','Fjob','reason','guardian',
            'schoolsup','famsup','paid','activities','nursery','higher','internet','romantic']
ordinal = ['Medu','Fedu','traveltime','studytime','failures','famrel','freetime','goout','Dalc','Walc','health']
numeric = ['age','absences']

for i in norminal+ordinal:
    print(math[i].unique())
    print(por[i].unique())
# Out:
# ['GP' 'MS']
# ['GP' 'MS']
# ['F' 'M']
# ['F' 'M']
# ['U' 'R']
# ['U' 'R']
# ['GT3' 'LE3']
# ['GT3' 'LE3']
# ['A' 'T']
# ['A' 'T']
# ['at_home' 'health' 'other' 'services' 'teacher']
# ['at_home' 'health' 'other' 'services' 'teacher']
# ['teacher' 'other' 'services' 'health' 'at_home']
# ['teacher' 'other' 'services' 'health' 'at_home']
# ['course' 'other' 'home' 'reputation']
# ['course' 'other' 'home' 'reputation']
# ['mother' 'father' 'other']
# ['mother' 'father' 'other']
# ['yes' 'no']
# ['yes' 'no']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['yes' 'no']
# ['yes' 'no']
# ['yes' 'no']
# ['yes' 'no']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# ['no' 'yes']
# [4 1 3 2 0]
# [4 1 3 2 0]
# [4 1 2 3 0]
# [4 1 2 3 0]
# [2 1 3 4]
# [2 1 3 4]
# [2 3 1 4]
# [2 3 1 4]
# [0 3 2 1]
# [0 3 1 2]
# [4 5 3 1 2]
# [4 5 3 1 2]
# [3 2 4 1 5]
# [3 2 4 1 5]
# [4 3 2 1 5]
# [4 3 2 1 5]
# [1 2 5 3 4]
# [1 2 5 3 4]
# [1 3 2 4 5]
# [1 3 2 4 5]
# ...

# %% [markdown]
# ## 2.5 Univariate Outliers Detection
# - 1. scatter
# - 2. boxplot
# - 3. z-score

# %% [markdown]
# ## note. *****
# - drop ข้อมูลที่ G3 == 0
# เนืองจาก:
#     - ข้อมูลมีความผิดปรกติ สังเกตุจาก ผู้ที่ได้เกรด 0 ทุกคน เป็นคนที่ absense == 0 (ไม่เคยขาดเรียนเลย) ซึ่งขัดแย้งกัน, ข้อมูลอาจจะเป็นความหมายในลักษณะอื่น เช่น drop เรียนนั้นๆ
#     - จาก outlier detection (z-score) อาจมองข้อมูลดังกล่าวเป็น outlier ได้
#
# ### ============*****

# %%
plt.rcParams.update({'font.size':12})
sns.kdeplot(math['G3'],label='G3 Math',)
sns.kdeplot(por['G3'],label='G3 Port',linestyle='--')
plt.title('G3 distribution on Math and Port.')
plt.ylim(0,0.16)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(math.index,math['G3'],hue='absences',data=math,palette='rocket_r')
plt.title('G3 Math - Students')
plt.xlabel('Index')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(por.index,por['G3'],hue='absences',data=por,palette='rocket_r')
plt.title('G3 Portuguese - Students')
plt.xlabel('Index')
plt.show()

# %%
sns.boxplot('G3',data=math,color='salmon')
sns.swarmplot('G3',data=math,color='.25')
plt.title('G3 Math')
plt.show()

# %%
sns.boxplot('G3',data=por,color='salmon')
sns.swarmplot('G3',data=por, color='.25')
plt.title('G3 Portuguese')
plt.show()

# %%
def z_G3(dataframe):
    mu = dataframe['G3'].mean()
    sd = dataframe['G3'].std()
    z = (dataframe['G3']-mu)/sd
    dataframe['z'] = z
    return dataframe
math = z_G3(math)
por = z_G3(por)

# %%
print(math[(math['z']<-2)|(math['z']>2)].shape)
math[(math['z']<-2)|(math['z']>2)]
# Out:
# (39, 34)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 47      GP   M   16       U     GT3       T     4     3    health  services
# 128     GP   M   18       R     GT3       T     2     2  services     other
# 130     GP   F   15       R     GT3       T     3     4  services   teacher
# 131     GP   F   15       U     GT3       T     1     1   at_home     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 135     GP   F   15       U     GT3       T     4     4  services   at_home
# 136     GP   M   17       R     GT3       T     3     4   at_home     other
# 137     GP   F   16       U     GT3       A     3     3     other     other
# 140     GP   M   15       U     GT3       T     4     3   teacher  services
# 144     GP   M   17       U     GT3       T     2     1     other     other
# 146     GP   F   15       U     GT3       T     3     2    health  services
# ...

# %%
print(por[(por['z']<-2)|(por['z']>2)].shape)
por[(por['z']<-2)|(por['z']>2)]
# Out:
# (19, 34)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 163     GP   M   18       U     LE3       T     1     1     other     other
# 172     GP   M   16       U     GT3       T     3     3     other  services
# 279     GP   M   22       U     GT3       T     3     1  services  services
# 338     GP   F   17       R     LE3       T     3     1  services     other
# 440     MS   M   16       U     GT3       T     1     1   at_home  services
# 519     MS   M   16       R     GT3       T     2     1     other  services
# 563     MS   M   17       U     GT3       T     2     2     other     other
# 567     MS   M   18       R     GT3       T     3     2  services     other
# 583     MS   F   18       R     GT3       T     2     2     other     other
# 586     MS   F   17       U     GT3       T     4     2   teacher  services
# 597     MS   F   18       R     GT3       T     2     2   at_home     other
# ...

# %% [markdown]
# - Now delete data for those have z(G3) less than -2.2 on both Math and Portuguese

# %%
def drop_outlier(dataframe):
    idx = dataframe[dataframe['z']< -2.2].index
    dataframe.drop(idx,inplace=True)
    return dataframe
math = drop_outlier(math)
por = drop_outlier(por)

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(math.index,math['G3'],data=math,palette='husl')
plt.title('G3 Math - Students')
plt.xlabel('Index')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(por.index,por['G3'],data=por,palette='husl')
plt.title('G3 Portuguese - Students')
plt.xlabel('Index')
plt.show()

# %% [markdown]
# ## note.
#
# #### consider -> absences outlier

# %%
def z_absen(dataframe):
    mu = np.mean(dataframe['absences'])
    sd = np.mean(dataframe['absences'])
    z = (dataframe['absences']-mu)/sd
    dataframe['z_absen'] = z
    return dataframe

# math = z_absen(math)
# por = z_absen(por)
# z score สูง หลายตัวมาก เบ้ขวา ใช้เกณฑ์อะไรตัด

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(math.index,math.absences,hue='school',data=math)
plt.title('G3 Math - Students')
plt.xlabel('Index')
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(por.index,por.absences,hue='school',data=por)
plt.title('G3 Portuguese - Students')
plt.xlabel('Index')
plt.show()

# %%
sns.kdeplot(math['absences'],label='G3 Math',)
sns.kdeplot(por['absences'],label='G3 Port',linestyle='--')

# %%
# DBScan
from sklearn.cluster import DBSCAN

model = DBSCAN(eps=5,min_samples=2,metric = 'euclidean')

cluster_math = model.fit_predict(math[['absences']])
cluster_por = model.fit_predict(por[['absences']])

# %%
math[cluster_math==-1]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu   Mjob      Fjob  ...  \
# 276     GP   F   18       R     GT3       A     3     2  other  services  ...
#
#     freetime goout  Dalc  Walc  health absences  G1 G2 G3         z
# 276        1     1     1     1       5       75  10  9  9 -0.308896
#
# [1 rows x 34 columns]

# %%
por[cluster_por==-1]
# Out:
# Empty DataFrame
# Columns: [school, sex, age, address, famsize, Pstatus, Medu, Fedu, Mjob, Fjob, reason, guardian, traveltime, studytime, failures, schoolsup, famsup, paid, activities, nursery, higher, internet, romantic, famrel, freetime, goout, Dalc, Walc, health, absences, G1, G2, G3, z]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# ## end note. ------------------ ****

# %% [markdown]
# ## 2.6 Data Exploration
# - let's G3 be the only dependent variable on both Math and Portuguese
# - 1 G3 Math and independent variables
# - 2 G3 Portuguese and independent variables
# - 3 G3 Math and G3 Portuguese Distribution
# - 4 G3 Score and School
# - 5 Gender and G3 Score on both Math and Portuguese
# - 6 Internet and G3 Score on both Math and Portuguese
# - 7 Family support on education and G3 Score on both Math and Portuguese
# - 8 Father Occupations and G3 Score on both Math and Portuguese
# - 9 Mother Occupations and G3 Score on both Math and Portuguese
# - 10 Study time and G3 Score on both Math and Portuguese
# - 11 Workday Alcohol Consumption and G3 Score on both Math and Portuguese
# - 12 Weekend Alcohol Consumption and G3 Score on both Math and Portuguese

# %% [markdown]
# ## 2.6.1 G3 Math and independent variables

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.pairplot(x_vars =  math.columns,y_vars = ['G3'],data = math )
plt.show()

# %% [markdown]
# ## 2.6.2 G3 Portuguese and independent variables

# %%
import seaborn as sns
sns.set_style('darkgrid')
sns.pairplot(x_vars =  por.columns,y_vars = ['G3'],data = por )
plt.show()

# %%
math['subject'] = 'Math'
por['subject'] = 'Portuguese'
df = pd.concat([math,por])
print(df.shape)
df.sample(5)
# Out:
# (990, 35)
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob   Fjob  ...  \
# 51      GP   F   15       U     LE3       T     4     2    health  other  ...
# 574     MS   M   20       R     GT3       T     1     1     other  other  ...
# 307     GP   M   17       U     GT3       T     3     1  services  other  ...
# 1       GP   F   17       U     GT3       T     1     1   at_home  other  ...
# 601     MS   F   18       U     GT3       T     2     2     other  other  ...
#
#     goout Dalc  Walc  health  absences  G1  G2  G3         z     subject
# 51      3    1     1       5         2  11  13  13  0.564191        Math
# 574     3    2     4       4        12   8  11  10 -0.589976  Portuguese
# 307     4    3     4       5         0  11  11  14  0.648163  Portuguese
# 1       3    1     1       3         2   9  11  11 -0.280441  Portuguese
# 601     1    1     1       2         4   8   8  10 -0.589976  Portuguese
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 2.6.3 G3 Math and G3 Portuguese Distribution

# %%
plt.rcParams.update({'font.size':12})
sns.kdeplot(math['G3'],label='G3 Math',)
sns.kdeplot(por['G3'],label='G3 Port',linestyle='--')
plt.title('G3 distribution on Math and Port.')
plt.ylim(0,0.16)
plt.legend()
plt.show()

# %%
sns.histplot(data=df,x='G3',bins=20,hue='subject')
plt.title('G3 distribution on Math and Port.')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-87d030fd9dfa> in <module>
# ----> 1 sns.histplot(data=df,x='G3',bins=20,hue='subject')
#       2 plt.title('G3 distribution on Math and Port.')
#       3
#       4 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'histplot'

# %% [markdown]
# After elimination of G3 outliers for Math and Portuguese Dataframe, both G3 Math and G3 Portuguese have normal distribution.

# %% [markdown]
# ## 2.6.4 G3 Score and School
# - G3 Math and School
# - G3 Portuguese and School

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['school']=='MS']['G3'],label='MS')
sns.kdeplot(math[math['school']=='GP']['G3'],label='GP',linestyle='--')
plt.title('G3 Math of MS and GP school')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['school']=='MS']['G3'],label='MS')
sns.kdeplot(por[por['school']=='GP']['G3'],label='GP', linestyle='--')

plt.title('G3 Portuguese of MS and GP school')
plt.legend()
plt.show()

# %% [markdown]
# - GP Students obviously overperform MS Students on both Math and Portuguese subjects

# %% [markdown]
# ## 2.6.5 Gender and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['sex']=='M']['G3'],label='M')
sns.kdeplot(math[math['sex']=='F']['G3'],label='F',linestyle='--')
plt.title('G3 Math of Male and Female')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['sex']=='M']['G3'],label='M')
sns.kdeplot(por[por['sex']=='F']['G3'],label='F',linestyle='--')
plt.title('G3 Portuguese of Male and Female')
plt.legend()
plt.show()

# %% [markdown]
# It seems that Gender is not associated with G3 score on these two subjects

# %% [markdown]
# ## 2.6.6 Internet and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['internet']=='yes']['G3'],label='Yes')
sns.kdeplot(math[math['internet']=='no']['G3'],label='No',linestyle='--')
plt.title('G3 Math and Internet Access')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['internet']=='yes']['G3'],label='Yes')
sns.kdeplot(por[por['internet']=='no']['G3'],label='No',linestyle='--')
plt.title('G3 Portuguese and Internet Access')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.6.7 Family support on education and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(10,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['famsup']=='yes']['G3'],label='Yes')
sns.kdeplot(math[math['famsup']=='no']['G3'],label='No',linestyle='--')
plt.title('G3 Math and Family Support on Education')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['famsup']=='yes']['G3'],label='Yes')
sns.kdeplot(por[por['famsup']=='no']['G3'],label='No',linestyle='--')
plt.title('G3 Portuguese and Family Support on Education')
plt.legend()
plt.show()

# %% [markdown]
# - No different performance between those who are educationally supported by family

# %% [markdown]
# ## 2.6.8 Father Occupations and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['Fjob']=='teacher']['G3'],label='teacher')
sns.kdeplot(math[math['Fjob']=='other']['G3'],label='other')
sns.kdeplot(math[math['Fjob']=='services']['G3'],label='services')
sns.kdeplot(math[math['Fjob']=='health']['G3'],label='health')
sns.kdeplot(math[math['Fjob']=='at_home']['G3'],label='at_home')
plt.title('G3 Math and Father Occupations')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['Fjob']=='teacher']['G3'],label='teacher')
sns.kdeplot(por[por['Fjob']=='other']['G3'],label='other')
sns.kdeplot(por[por['Fjob']=='services']['G3'],label='services')
sns.kdeplot(por[por['Fjob']=='health']['G3'],label='health')
sns.kdeplot(por[por['Fjob']=='at_home']['G3'],label='at_home')
plt.title('G3 Portuguese and Father Occupations')
plt.legend()
plt.show()

# %% [markdown]
# - It seems that if his father is a teacher, the student tends to perform well on both math and portuguese

# %% [markdown]
# ## 2.6.9 Mother Occupations and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['Mjob']=='teacher']['G3'],label='teacher')
sns.kdeplot(math[math['Mjob']=='other']['G3'],label='other')
sns.kdeplot(math[math['Mjob']=='services']['G3'],label='services')
sns.kdeplot(math[math['Mjob']=='health']['G3'],label='health')
sns.kdeplot(math[math['Mjob']=='at_home']['G3'],label='at_home')
plt.title('G3 Math and Mother Occupations')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['Mjob']=='teacher']['G3'],label='teacher')
sns.kdeplot(por[por['Mjob']=='other']['G3'],label='other')
sns.kdeplot(por[por['Mjob']=='services']['G3'],label='services')
sns.kdeplot(por[por['Mjob']=='health']['G3'],label='health')
sns.kdeplot(por[por['Mjob']=='at_home']['G3'],label='at_home')
plt.title('G3 Portuguese and Mother Occupations')
plt.legend()
plt.show()

# %% [markdown]
# For mother occupations, there seems to be a slight trend that if a mother stays at home, her child may not perform well on both subjects

# %% [markdown]
# ## 2.6.10 Study time and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['studytime']==1]['G3'],label='1')
sns.kdeplot(math[math['studytime']==2]['G3'],label='2')
sns.kdeplot(math[math['studytime']==3]['G3'],label='3')
sns.kdeplot(math[math['studytime']==4]['G3'],label='4')
plt.title('G3 Math and Study time')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['studytime']==1]['G3'],label='1')
sns.kdeplot(por[por['studytime']==2]['G3'],label='2')
sns.kdeplot(por[por['studytime']==3]['G3'],label='3')
sns.kdeplot(por[por['studytime']==4]['G3'],label='4')
plt.title('G3 Portuguese and Study time')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.6.11 Workday Alcohol Consumption and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['Dalc']==1]['G3'],label='1')
sns.kdeplot(math[math['Dalc']==2]['G3'],label='2')
sns.kdeplot(math[math['Dalc']==3]['G3'],label='3')
sns.kdeplot(math[math['Dalc']==4]['G3'],label='4')
sns.kdeplot(math[math['Dalc']==5]['G3'],label='5')

plt.title('G3 Math and Workday Alcohol Consumption')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['Dalc']==1]['G3'],label='1')
sns.kdeplot(por[por['Dalc']==2]['G3'],label='2')
sns.kdeplot(por[por['Dalc']==3]['G3'],label='3')
sns.kdeplot(por[por['Dalc']==4]['G3'],label='4')
sns.kdeplot(por[por['Dalc']==5]['G3'],label='5')
plt.title('G3 Portuguese and Workday Alcohol Consumption')
plt.legend()
plt.show()

# %% [markdown]
# ## 2.6.12 Weekend Alcohol Consumption and G3 Score on both Math and Portuguese

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax = plt.subplot(1,2,1)
sns.kdeplot(math[math['Walc']==1]['G3'],label='1')
sns.kdeplot(math[math['Walc']==2]['G3'],label='2')
sns.kdeplot(math[math['Walc']==3]['G3'],label='3')
sns.kdeplot(math[math['Walc']==4]['G3'],label='4')
sns.kdeplot(math[math['Walc']==5]['G3'],label='5')

plt.title('G3 Math and Weekend Alcohol Consumption')
plt.legend()

ax = plt.subplot(1,2,2)
sns.kdeplot(por[por['Walc']==1]['G3'],label='1')
sns.kdeplot(por[por['Walc']==2]['G3'],label='2')
sns.kdeplot(por[por['Walc']==3]['G3'],label='3')
sns.kdeplot(por[por['Walc']==4]['G3'],label='4')
sns.kdeplot(por[por['Walc']==5]['G3'],label='5')
plt.title('G3 Portuguese and Weekend Alcohol Consumption')
plt.legend()
plt.show()

# %% [markdown]
# _____

# %% [markdown]
# # - Start with Math Dataframe

# %% [markdown]
# # 3. Preprocessing Data

# %% [markdown]
# ## 3.1 Function for LabelEncoding and StandardScaler

# %%
def labelEncode(dataframe,columns):
    
    '''
    This function is for labeling nominal data. The function takes two arguments which are dataframe and nominal columns. 
    It returns:
    1) dataframe with labeled columns_ ,
    2) lb_object which would be used later during after prediction process, and 
    3) classes of those columns that are labeled
    '''
    
    from sklearn.preprocessing import LabelEncoder
    classes = dict()
    lb_object = dict()
    for column in columns:
        lb = LabelEncoder()
        after_lb = lb.fit_transform(dataframe[column])
        classes[column] = lb.classes_
        dataframe[column+'_lb'] = after_lb
        lb_object[column] = lb
    return dataframe, lb_object, classes

def standardScaler(dataframe,columns):
    '''
    This function is for z-standard normalization. This function takes two arguments which are dataframe and numeric columns.
    It returns:
    1) dataframe with standardized columns, 
    2) mean of data in such columns as dictionary datatype, 
    3) standard deviation of data in such columns as dictionary datatype and
    4) stantdard scaler object. This will be used later using prediction new data for converting data to be the same distribution as training data
    '''
    
    from sklearn.preprocessing import StandardScaler
    mean = dict()
    sd = dict()
    scaler = StandardScaler()
    scaler.fit(df[columns])
    for index,column in enumerate(columns):
        mean[column] = scaler.mean_[index]
        sd[column] = np.sqrt(scaler.var_)[index]
    dataframe[columns] = scaler.transform(dataframe[columns])    
    return dataframe, scaler, mean, sd,

# %% [markdown]
# ## 3.2 Apply labelEncode function and standardScaler function and drop irrelavant columns

# %%
# Data type in math dataframe
nominal = ['school','sex','address','famsize','Pstatus','Mjob','Fjob','reason','guardian',
            'schoolsup','famsup','paid','activities','nursery','higher','internet','romantic']
ordinal = ['Medu','Fedu','traveltime','studytime','failures','famrel','freetime','goout','Dalc','Walc','health','G2','G3']
numeric = ['age','absences']

# drop irrelavant columns
df = math.copy()
drop_columns = ['z','subject','G1','G2']
df = df.drop(drop_columns,axis=1)

# get_dummies
df = pd.get_dummies(data=df, columns=nominal)

# StandardScaler for numeric data
df, scaler, mean, sd = standardScaler(df,numeric) 

# drop columns that are not labeled and reset index
# df.drop(nominal,axis=1,inplace=True) **
df.reset_index(drop=True,inplace=True)
df
# Out:
#           age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    1.061630     4     4           2          2         0       4         3
# 1    0.272043     1     1           1          2         0       5         3
# 2   -1.307132     1     1           1          2         3       4         3
# 3   -1.307132     4     2           1          3         0       3         2
# 4   -0.517545     3     3           1          2         0       4         3
# ..        ...   ...   ...         ...        ...       ...     ...       ...
# 352  2.640805     2     2           1          2         2       5         5
# 353  0.272043     3     1           2          1         0       2         4
# 354  3.430392     1     1           1          1         3       5         5
# 355  1.061630     3     2           3          1         0       4         4
# 356  1.851217     1     1           1          1         0       3         2
#
# ...

# %% [markdown]
# ## 3.3 Checking Datatype of each columns before modeling

# %%
# all data are in numeric
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 57 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                357 non-null    float64
#  1   Medu               357 non-null    int64
#  2   Fedu               357 non-null    int64
#  3   traveltime         357 non-null    int64
#  4   studytime          357 non-null    int64
#  5   failures           357 non-null    int64
#  6   famrel             357 non-null    int64
#  7   freetime           357 non-null    int64
#  8   goout              357 non-null    int64
#  9   Dalc               357 non-null    int64
#  10  Walc               357 non-null    int64
#  11  health             357 non-null    int64
#  12  absences           357 non-null    float64
#  13  G3                 357 non-null    int64
#  14  school_GP          357 non-null    uint8
#  15  school_MS          357 non-null    uint8
# ...

# %% [markdown]
# ## 3.4 Re-check correlation between G3(target) and features

# %%
plt.figure(figsize=(5,10))
ax = sns.heatmap(df.corr()[['G3']].sort_values(by='G3',ascending=False),annot=True,cmap='YlGnBu')
ax.set(title='Correlation between G3 and Features-Math data')
plt.show()

# %% [markdown]
# # 4. Model Building
# - Objective: 1.) Predict Students' Grade(G3). Since G3 is discrete data, hence it is classification problem
# - Note that: In math dataframe, there are only 357 samples. Therefore, K-Fold cross validation is needed
#     - 57 samples for test set
#     - 300 samples for training and 10 folds cross validation
# - 4.1 Seperate data for traning,
# - 4.2 Modeling Building by each algorithms
#     - 1.) Decision Tree
#     - 2.) RandomForestClassifier
#     - 3.) Support Vector Machine
#     - 4.) GaussianNB
# - 4.3 Select model and test with unseen data

# %%
from sklearn.model_selection import KFold, cross_val_score,train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
def plot_model_performance(dataframe):
    '''
    This function is for plotting model performance (Measure accuracy)
    '''
    cols=dataframe.columns
    dataframe[cols].plot.box(figsize=(9,5))
    plt.title('Model Performance (Accuracy)')
    plt.xlabel('Model')
    plt.ylabel('Accuracy')
    for i,col in enumerate(cols):
        plt.text(0.5+i,dataframe[col].mean(),'mean: {:.2f}%'.format(dataframe[col].mean()*100))
    return plt.show()

def plot_confusion_matrix(y_test,y_pred):
    '''
    This function is for plotting confusion matrix to evaluate model performance
    '''
    cm = confusion_matrix(y_test,y_pred)
    target_class = np.sort(y_test.unique())
    plt.rcParams.update({'font.size':13})
    plt.figure(figsize=(8,6))
    ax = sns.heatmap(cm,annot=True,cmap='YlGnBu')
    ax.set(title='Confusion Matrix',xlabel='Prediction',ylabel='Actual')
    ax.xaxis.set_ticklabels(target_class)
    ax.yaxis.set_ticklabels(target_class)
    plt.show()

# %% [markdown]
# ## 4.1 Seperate Data for training and testing

# %% [markdown]
# ## 4.2 Modeling Building by each algorithms

# %%
df = df.sample(frac=1).reset_index(drop=True) # shuffle data
n_training_size = 300
train = df.iloc[:n_training_size,:]
test = df.iloc[n_training_size+1:,:]

X_test = test.drop(['G3'],axis=1)
y_test = test['G3']

target = ['G3']
features = df.drop(target,axis=1).columns

k_folds = 10
models = [DecisionTreeClassifier(), 
          RandomForestClassifier(),
          SVC(kernel='rbf'),
          GaussianNB()]   # Model instantiation
model_names = ['DecisionTree','RandomForest','SupportVectorMachine','NaiveBayes']
model_acc_score = dict()

for i,model in enumerate(models):
    train = df.iloc[:n_training_size,:]
    acc_score = list()
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
        # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

        # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]
        
        # fit and predict model
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        acc_score.append(accuracy_score(y_val,y_pred))
    model_acc_score[model_names[i]] = acc_score
df_acc_score = pd.DataFrame(model_acc_score,index=['Round'+str(i+1) for i in range(k_folds)])
print('Mean Accuracy - Summary of {} Folds Cross Validation'.format(k_folds))
print('_______________________')
print(df_acc_score.mean())
print(df_acc_score)
plot_model_performance(df_acc_score)
# Out:
# Mean Accuracy - Summary of 10 Folds Cross Validation
# _______________________
# DecisionTree            0.106667
# RandomForest            0.146667
# SupportVectorMachine    0.163333
# NaiveBayes              0.050000
# dtype: float64
#          DecisionTree  RandomForest  SupportVectorMachine  NaiveBayes
# Round1       0.033333      0.266667              0.133333    0.066667
# Round2       0.066667      0.066667              0.166667    0.133333
# Round3       0.300000      0.166667              0.300000    0.000000
# Round4       0.100000      0.133333              0.100000    0.000000
# Round5       0.133333      0.166667              0.166667    0.000000
# Round6       0.066667      0.100000              0.033333    0.100000
# Round7       0.066667      0.200000              0.100000    0.133333
# Round8       0.133333      0.166667              0.333333    0.000000
# Round9       0.066667      0.100000              0.133333    0.033333
# ...

# %% [markdown]
# The mean accuracy score offered by each model are very low, approximately 10%.Nonetheless, if we subtly consider the predicted value and true value, we can clearly see that predicted values only slightly differ from true value. Therefore, it is reasonable to create a new metric that loosely measure the prediction accuracy. To elaborate, this metric is going to give the score to a model that offers predicted value differed from true value by 2 unit as correct prediction. For example, true value = 7, predicted value = 9 -> correct prediction

# %%
def prediction_adjusted(y_test,y_pred,diff=2):
    '''
    This function is for adjusting the value of the prediction. 
    If the model predict the value differed from true value by 1 unit, 
    it is going to change such predicted value to be equal to true value.
    '''
    y_test = y_test.values.ravel()
    y_pred = np.array(y_pred)
    y_pred_adj = np.where(np.absolute(y_pred-y_test)<=diff,y_test,y_pred)
    return y_pred_adj

# %%
df = df.sample(frac=1).reset_index(drop=True) # shuffle data
n_training_size = 300
train = df.iloc[:n_training_size,:]
test = df.iloc[n_training_size+1:,:]

X_test = test.drop(['G3'],axis=1)
y_test = test['G3']

target = ['G3']
features = df.drop(target,axis=1).columns

k_folds = 10
models = [DecisionTreeClassifier(), 
          RandomForestClassifier(),
          SVC(kernel='rbf'),
          GaussianNB(),]   # Model instantiation
model_names = ['DecisionTree','RandomForest','SupportVectorMachine','NaiveBayes']
model_acc_score = dict()

for i,model in enumerate(models):
    train = df.iloc[:n_training_size,:]
    acc_score = list()
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
        # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

        # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]
        
        # fit and predict model
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        acc_score.append(accuracy_score(y_val,y_pred_adj))
    model_acc_score[model_names[i]] = acc_score
df_acc_score = pd.DataFrame(model_acc_score,index=['Round'+str(i+1) for i in range(k_folds)])
print('Mean Accuracy - Summary of {} Folds Cross Validation'.format(k_folds))
print('_______________________')
print(df_acc_score.mean())
print(df_acc_score)
plot_model_performance(df_acc_score)
# Out:
# Mean Accuracy - Summary of 10 Folds Cross Validation
# _______________________
# DecisionTree            0.463333
# RandomForest            0.520000
# SupportVectorMachine    0.530000
# NaiveBayes              0.273333
# dtype: float64
#          DecisionTree  RandomForest  SupportVectorMachine  NaiveBayes
# Round1       0.500000      0.500000              0.533333    0.166667
# Round2       0.566667      0.633333              0.633333    0.233333
# Round3       0.500000      0.666667              0.700000    0.166667
# Round4       0.466667      0.500000              0.533333    0.333333
# Round5       0.433333      0.400000              0.466667    0.300000
# Round6       0.600000      0.433333              0.366667    0.400000
# Round7       0.200000      0.366667              0.500000    0.366667
# Round8       0.400000      0.466667              0.466667    0.300000
# Round9       0.500000      0.533333              0.433333    0.166667
# ...

# %% [markdown]
# ## 4.3 Select model and test with unseen data
# By considering models' performance (accuracy metrics), support vector machine model and random forest classifier models tend to offer the most promising result because these two model provide highest accuracy levels. Therefore, support vector machine and random forest are selected to test with unseen data. Also these two models will be taken to tuning process later so that we can make the final decision that which model is better.

# %% [markdown]
# # 5. Model Evaluation
# - Testing with unseen data
# - Metrics: Accuracy Score, Confusion Matrix, Classification Report

# %% [markdown]
# ## 5.1 Test SVC model with unseen data

# %%
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("SVC Performance Evaluation: Tesing with unseen data")
print('')
print('Y-True:',np.array(y_test).ravel())
print('')
print('Y-Predict',y_pred)
print('')
print('Y-Predict-Adjusted:',y_pred_adj)
print('')
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
# Out:
# SVC Performance Evaluation: Tesing with unseen data
#
# Y-True: [ 9 12 13  9 18  8 15 14  9  8  5 11 10 18 12 10 14  9 11 18 12 12 16 13
#  10  9 18 11 10 12 15 11 12 16 11 10 14  8 12 11 19 10 10 12 14 15  9  8
#  14 12 16 11 10 11 17 10]
#
# Y-Predict [11 10 10  8 11 10 10 10 10 10 10 10 10 11 10 10 10 11 10 10 10 10 10 10
#  10 10 10 10 10 10 10 11 10 10 10 10 15 11 11 11 10 10 11 11 11 10 10 10
#  10 10 11 11 10 11 11 10]
#
# Y-Predict-Adjusted: [ 9 12 10  9 11  8 10 10  9  8 10 11 10 11 12 10 10  9 11 10 12 12 10 10
#  10  9 10 11 10 12 10 11 12 10 11 10 14 11 12 11 10 10 10 12 11 10  9  8
#  10 12 11 11 10 11 11 10]
#
# Accuracy_score 64.29%
#
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         1
#            8       1.00      0.75      0.86         4
#            9       1.00      1.00      1.00         6
#           10       0.39      1.00      0.56         9
#           11       0.57      1.00      0.73         8
# ...

# %% [markdown]
# ## 5.2 Test Random Forest Classifier model with unseen data

# %%
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("Random Forest Classifier Performance Evaluation: Tesing with unseen data")
print('')
print('Y-True:',np.array(y_test).ravel())
print('')
print('Y-Predict',y_pred)
print('')
print('Y-Predict-Adjusted:',y_pred_adj)
print('')
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
# Out:
# Random Forest Classifier Performance Evaluation: Tesing with unseen data
#
# Y-True: [ 9 12 13  9 18  8 15 14  9  8  5 11 10 18 12 10 14  9 11 18 12 12 16 13
#  10  9 18 11 10 12 15 11 12 16 11 10 14  8 12 11 19 10 10 12 14 15  9  8
#  14 12 16 11 10 11 17 10]
#
# Y-Predict [11 10 12  8 14 10 11 10  9 10 13 10 11 15 11 13 14 11 13 15 13 10 10 13
#  10  7 15 10  8  8 12 13 14 10 11 13 15 13 11 11 15  8 13 13 14 10 11 10
#  10 11 13 15 10  6 15 10]
#
# Y-Predict-Adjusted: [ 9 12 13  9 14  8 11 10  9  8 13 11 10 15 12 13 14  9 11 15 12 12 10 13
#  10  9 15 11 10  8 12 11 12 10 11 13 14 13 12 11 15 10 13 12 14 10  9  8
#  10 12 13 15 10  6 17 10]
#
# Accuracy_score 62.50%
#
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         1
#            6       0.00      0.00      0.00         0
#            8       0.75      0.75      0.75         4
#            9       1.00      1.00      1.00         6
# ...

# %% [markdown]
# These two models seem to provide the same level of accuracy (approximately = 50%-60%) for prediction.

# %% [markdown]
# # 6. Model Improvement
# - 6.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model
#     - Re-train SVC model and evaluate performance - name: model_svc_math
# - 6.2.1 Optimize model by changing hyperparameter and measure the performance via visualization.
#     - Re-train randomforest model and evaluate - name: model_RNF1_math
# - 6.2.2 RandomoizeSearchCV for tuning the model
#     - Re-train randomforest model and evaluate - name: model_RNF2_math

# %%
# for collecting model and its accuracy after tuning parameter
model_acc_math = dict()

# %% [markdown]
# ## 6.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model

# %%
from sklearn.model_selection import RandomizedSearchCV
model = SVC()
param_dict_SVC = {'C':[0.1,1,10,50],
             'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':[10,1,0.5,0.1],
             'shrinking':[True,False],
             'coef0' :[0.0,0.1,0.5]}
param_dict_svc= RandomizedSearchCV(model, param_dict_SVC, cv=10,n_iter = 100,scoring='accuracy',verbose=1)
param_dict_svc.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# RandomizedSearchCV(cv=10, estimator=SVC(), n_iter=100,
#                    param_distributions={'C': [0.1, 1, 10, 50],
#                                         'coef0': [0.0, 0.1, 0.5],
#                                         'gamma': [10, 1, 0.5, 0.1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid'],
#                                         'shrinking': [True, False]},
#                    scoring='accuracy', verbose=1)

# %%
param_dict_svc.best_params_
# Out:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 0.1, 'coef0': 0.5, 'C': 10}

# %% [markdown]
# #### Re-train SVC model and evaluate performance

# %%
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]

model_svc_math = SVC(C=param_dict_svc.best_params_['C'],
            coef0 = param_dict_svc.best_params_['coef0'], 
            gamma =param_dict_svc.best_params_['gamma'], 
            kernel=param_dict_svc.best_params_['kernel'],
            shrinking=param_dict_svc.best_params_['shrinking'])
model_svc_math.fit(X_train,y_train)
y_pred = model_svc_math.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("SVC-After tuning: Tesing with unseen data")
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
model_acc_math[model_svc_math] = accuracy_score(y_test,y_pred_adj)*100
# Out:
# SVC-After tuning: Tesing with unseen data
# Accuracy_score 60.71%
#
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         1
#            8       0.75      0.75      0.75         4
#            9       0.83      0.83      0.83         6
#           10       0.50      0.78      0.61         9
#           11       0.67      0.75      0.71         8
#           12       1.00      1.00      1.00         9
#           13       0.14      0.50      0.22         2
#           14       0.67      0.40      0.50         5
#           15       0.00      0.00      0.00         3
#           16       0.00      0.00      0.00         3
#           17       0.00      0.00      0.00         1
#           18       1.00      0.25      0.40         4
#           19       0.00      0.00      0.00         1
#
#     accuracy                           0.61        56
#    macro avg       0.43      0.40      0.39        56
# ...

# %% [markdown]
# After tuning the SVC model, its performance slightly improve. The accuracy gently increase from 54% to 59%

# %% [markdown]
# ## 6.2.1 Optimize RandomForestClassifier model by keep changing hyperparameters
# It is important to note that, when constructing the validation curves, the other parameters were held at their default values and we will be using all of the optimized values together in a single model.

# %%
# Hyperparameters
estimators = [100,300,500,800,1200]
max_features = ['auto','log2']
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 20]
min_samples_leaf = [1, 2, 5, 10]
param = {'n_estimators': estimators,
         'max_features':max_features,
         'max_depth':max_depth,
         'min_samples_split':min_samples_split,
         'min_samples_leaf':min_samples_leaf}
params_dict = dict()

# %%
# Optimize n_estimators
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
k_folds = 10

Train_accScore = list()
Val_accScore = list()
hyperparameter = param['n_estimators'] # Select hyperparameters

for i in hyperparameter:
    model = RandomForestClassifier(n_estimators = i) # Select hyperparameters
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
            # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

            # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]

            # fit and predict with X_val
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        val_acc = accuracy_score(y_val,y_pred_adj)
        Val_accScore.append(val_acc)

            # predict with X_train
        y_train_pred = model.predict(X_train)
        y_train_pred_adj = prediction_adjusted(y_train,y_train_pred)
        train_acc = accuracy_score(y_train,y_train_pred)
        Train_accScore.append(train_acc)

Train_accScore = np.array(Train_accScore).reshape(len(hyperparameter),k_folds)
Train_accuracy = np.mean(Train_accScore,axis=1)

Val_accScore = np.array(Val_accScore).reshape(len(hyperparameter),k_folds)
Validation_accuracy = np.mean(Val_accScore,axis=1)

df_temp = pd.DataFrame({'Train_accuracy':Train_accuracy,'Validation_accuracy':Validation_accuracy},index=hyperparameter)
params_dict['n_estimators'] = df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index

# %%
def plot_train_val_accuracy(dataframe,param_name):
    '''This function is for ploting training and validation accuracy curve'''
    ax = dataframe.plot(figsize=(7,4))
    ax.set(title='Train and Validation Accuracy',ylabel='Accuracy',xlabel='Value of hyperparameter {}'.format(param_name))
    ax.scatter(df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index[0],df_temp['Validation_accuracy'].max(),color='red') 
    plt.show()

# %%
df_temp
# Out:
#       Train_accuracy  Validation_accuracy
# auto             1.0             0.533333
# log2             1.0             0.530000

# %%
plot_train_val_accuracy(df_temp,'n_estimators')

# %% [markdown]
# n_estimators = 500 provides highest accuracy score for validation data

# %%
# Optimize max_features
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
k_folds = 10

Train_accScore = list()
Val_accScore = list()
hyperparameter = param['max_features'] # Select hyperparameters

for i in hyperparameter:
    model = RandomForestClassifier(max_features = i) # Select hyperparameters
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
            # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

            # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]

            # fit and predict with X_val
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        val_acc = accuracy_score(y_val,y_pred_adj)
        Val_accScore.append(val_acc)

            # predict with X_train
        y_train_pred = model.predict(X_train)
        y_train_pred_adj = prediction_adjusted(y_train,y_train_pred)
        train_acc = accuracy_score(y_train,y_train_pred)
        Train_accScore.append(train_acc)

Train_accScore = np.array(Train_accScore).reshape(len(hyperparameter),k_folds)
Train_accuracy = np.mean(Train_accScore,axis=1)

Val_accScore = np.array(Val_accScore).reshape(len(hyperparameter),k_folds)
Validation_accuracy = np.mean(Val_accScore,axis=1)

df_temp = pd.DataFrame({'Train_accuracy':Train_accuracy,'Validation_accuracy':Validation_accuracy},index=hyperparameter)
params_dict['max_features'] = df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index

df_temp
# Out:
#       Train_accuracy  Validation_accuracy
# auto             1.0             0.533333
# log2             1.0             0.526667

# %%
df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index
# Out:
# Index(['auto'], dtype='object')

# %%
plot_train_val_accuracy(df_temp,'max_features')

# %%
# Optimize max_depth
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
k_folds = 10

Train_accScore = list()
Val_accScore = list()
hyperparameter = param['max_depth'] # Select hyperparameters

for i in hyperparameter:
    model = RandomForestClassifier(max_depth = i) # Select hyperparameters
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
            # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

            # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]

            # fit and predict with X_val
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        val_acc = accuracy_score(y_val,y_pred_adj)
        Val_accScore.append(val_acc)

            # predict with X_train
        y_train_pred = model.predict(X_train)
        y_train_pred_adj = prediction_adjusted(y_train,y_train_pred)
        train_acc = accuracy_score(y_train,y_train_pred)
        Train_accScore.append(train_acc)

Train_accScore = np.array(Train_accScore).reshape(len(hyperparameter),k_folds)
Train_accuracy = np.mean(Train_accScore,axis=1)

Val_accScore = np.array(Val_accScore).reshape(len(hyperparameter),k_folds)
Validation_accuracy = np.mean(Val_accScore,axis=1)

df_temp = pd.DataFrame({'Train_accuracy':Train_accuracy,'Validation_accuracy':Validation_accuracy},index=hyperparameter)
params_dict['max_depth'] = df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index

df_temp
# Out:
#     Train_accuracy  Validation_accuracy
# 5         0.802593             0.540000
# 8         0.996296             0.556667
# 15        1.000000             0.526667
# 25        1.000000             0.526667
# 30        1.000000             0.550000

# %%
plot_train_val_accuracy(df_temp,'max_depth')

# %%
# Optimize min_samples_split
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
k_folds = 10

Train_accScore = list()
Val_accScore = list()
hyperparameter = param['min_samples_split'] # Select hyperparameters

for i in hyperparameter:
    model = RandomForestClassifier(min_samples_split = i) # Select hyperparameters
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
            # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

            # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]

            # fit and predict with X_val
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        val_acc = accuracy_score(y_val,y_pred_adj)
        Val_accScore.append(val_acc)

            # predict with X_train
        y_train_pred = model.predict(X_train)
        y_train_pred_adj = prediction_adjusted(y_train,y_train_pred)
        train_acc = accuracy_score(y_train,y_train_pred)
        Train_accScore.append(train_acc)

Train_accScore = np.array(Train_accScore).reshape(len(hyperparameter),k_folds)
Train_accuracy = np.mean(Train_accScore,axis=1)

Val_accScore = np.array(Val_accScore).reshape(len(hyperparameter),k_folds)
Validation_accuracy = np.mean(Val_accScore,axis=1)

df_temp = pd.DataFrame({'Train_accuracy':Train_accuracy,'Validation_accuracy':Validation_accuracy},index=hyperparameter)
params_dict['min_samples_split'] = df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index

df_temp
# Out:
#     Train_accuracy  Validation_accuracy
# 2         1.000000             0.553333
# 5         0.998889             0.530000
# 10        0.927778             0.533333
# 15        0.796667             0.530000
# 20        0.680000             0.536667

# %%
plot_train_val_accuracy(df_temp,'min_sample_split')

# %%
# Optimize min_sample_leaf
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
k_folds = 10

Train_accScore = list()
Val_accScore = list()
hyperparameter = param['min_samples_leaf'] # Select hyperparameters

for i in hyperparameter:
    model = RandomForestClassifier(min_samples_leaf = i) # Select hyperparameters
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
            # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

            # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]

            # fit and predict with X_val
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        val_acc = accuracy_score(y_val,y_pred_adj)
        Val_accScore.append(val_acc)

            # predict with X_train
        y_train_pred = model.predict(X_train)
        y_train_pred_adj = prediction_adjusted(y_train,y_train_pred)
        train_acc = accuracy_score(y_train,y_train_pred)
        Train_accScore.append(train_acc)

Train_accScore = np.array(Train_accScore).reshape(len(hyperparameter),k_folds)
Train_accuracy = np.mean(Train_accScore,axis=1)

Val_accScore = np.array(Val_accScore).reshape(len(hyperparameter),k_folds)
Validation_accuracy = np.mean(Val_accScore,axis=1)

df_temp = pd.DataFrame({'Train_accuracy':Train_accuracy,'Validation_accuracy':Validation_accuracy},index=hyperparameter)
params_dict['min_sample_leaf'] = df_temp[df_temp['Validation_accuracy']==df_temp['Validation_accuracy'].max()].index

df_temp
# Out:
#     Train_accuracy  Validation_accuracy
# 1         1.000000             0.536667
# 2         0.998889             0.533333
# 5         0.798519             0.546667
# 10        0.504815             0.550000

# %%
plot_train_val_accuracy(df_temp,'min_samples_leaf')

# %%
params_dict
# Out:
# {'n_estimators': Int64Index([300], dtype='int64'),
#  'max_features': Index(['auto'], dtype='object'),
#  'max_depth': Int64Index([8], dtype='int64'),
#  'min_samples_split': Int64Index([2], dtype='int64'),
#  'min_sample_leaf': Int64Index([10], dtype='int64')}

# %% [markdown]
# Therefore, hyperparameters that will be used in RandomForestClassifier model are

# %% [markdown]
# #### Re-train randomforest model and evaluate - name: model_RNF1_math

# %%
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]

model_RNF1_math = RandomForestClassifier(n_estimators= params_dict['n_estimators'][0],
                               max_features = params_dict['max_features'][0],
                               max_depth= params_dict['max_depth'][0],
                               min_samples_split= params_dict['min_samples_split'][0], 
                               min_samples_leaf= params_dict['min_sample_leaf'][0])
model_RNF1_math.fit(X_train,y_train)
y_pred = model_RNF1_math.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("RandomForest-After Optimization: Tesing with unseen data")
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
model_acc_math[model_RNF1_math] = accuracy_score(y_test,y_pred_adj)*100
# Out:
# RandomForest-After Optimization: Tesing with unseen data
# Accuracy_score 57.14%
#
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.50      0.50      0.50         6
#            9       1.00      1.00      1.00         3
#           10       0.55      1.00      0.71        12
#           11       0.50      0.90      0.64        10
#           12       1.00      1.00      1.00         2
#           13       0.00      0.00      0.00         2
#           14       0.67      1.00      0.80         2
#           15       0.00      0.00      0.00         4
#           16       0.00      0.00      0.00         4
#           17       1.00      1.00      1.00         1
#           18       0.00      0.00      0.00         3
#           19       0.00      0.00      0.00         3
#
# ...

# %% [markdown]
# ## 6.2.2 Using RandomizeSearchCV to find best hyperparameters

# %%
from sklearn.model_selection import RandomizedSearchCV
model = RandomForestClassifier()

estimators = [100,300,500,800,1200]
max_features = ['auto','log2']
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 20]
min_samples_leaf = [1, 2, 5, 10]

param_dict_RnF = dict(n_estimators = estimators, max_depth = max_depth,  
              min_samples_split = min_samples_split, 
             min_samples_leaf = min_samples_leaf)

param_dict= RandomizedSearchCV(model, param_dict_RnF, cv=10,n_iter = 100,scoring='accuracy',verbose=1)
param_dict.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'max_depth': [5, 8, 15, 25, 30],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [100, 300, 500, 800,
#                                                          1200]},
#                    scoring='accuracy', verbose=1)

# %%
param_dict.best_params_
# Out:
# {'n_estimators': 300,
#  'min_samples_split': 10,
#  'min_samples_leaf': 10,
#  'max_depth': 5}

# %% [markdown]
# #### Re-train randomforest model and evaluate - name: model_RNF2_math

# %%
train = df.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]

model_RNF2_math = RandomForestClassifier(n_estimators= param_dict.best_params_['n_estimators'],
                               max_features = 'auto',
                               max_depth=  param_dict.best_params_['max_depth'],
                               min_samples_split=param_dict.best_params_['min_samples_split'], 
                               min_samples_leaf=param_dict.best_params_['min_samples_leaf'])
model_RNF2_math.fit(X_train,y_train)
y_pred = model_RNF2_math.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("RandomForest-After GridSearchCV: Tesing with unseen data")
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
model_acc_math[model_RNF2_math] = accuracy_score(y_test,y_pred_adj)*100
# Out:
# RandomForest-After GridSearchCV: Tesing with unseen data
# Accuracy_score 53.57%
#
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         2
#            6       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         1
#            8       0.40      0.33      0.36         6
#            9       1.00      1.00      1.00         3
#           10       0.52      1.00      0.69        12
#           11       0.45      0.90      0.60        10
#           12       1.00      1.00      1.00         2
#           13       0.00      0.00      0.00         2
#           14       1.00      0.50      0.67         2
#           15       0.00      0.00      0.00         4
#           16       0.00      0.00      0.00         4
#           17       1.00      1.00      1.00         1
#           18       0.00      0.00      0.00         3
#           19       0.00      0.00      0.00         3
#
# ...

# %% [markdown]
# Therefore, select the model that give higest accuracy

# %%
model_acc_math
# Out:
# {SVC(C=1, gamma=0.1, shrinking=False): 55.35714285714286,
#  RandomForestClassifier(max_depth=8, min_samples_leaf=10, n_estimators=300): 57.14285714285714,
#  RandomForestClassifier(max_depth=5, min_samples_leaf=10, min_samples_split=10,
#                         n_estimators=300): 53.57142857142857}

# %% [markdown]
# ## 7 Portuguese Data- Re create the model for prediction portuguese score

# %%
por
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %% [markdown]
# ## 7.1 Preprocess Portuguese data

# %% [markdown]
# ### 7.1.1 Apply labelEncode function and standardScaler function and drop irrelavant columns for Portuguese data

# %%
# Data type in math dataframe
nominal = ['school','sex','address','famsize','Pstatus','Mjob','Fjob','reason','guardian',
            'schoolsup','famsup','paid','activities','nursery','higher','internet','romantic']
ordinal = ['Medu','Fedu','traveltime','studytime','failures','famrel','freetime','goout','Dalc','Walc','health','G2','G3']
numeric = ['age','absences']

# drop irrelavant columns
df_por = por.copy()
drop_columns = ['z','subject','G1','G2']
df_por = df_por.drop(drop_columns,axis=1)

# # labelEncoder for nominal data
# df_por, lb_object, classes = labelEncode(df_por,nominal) **

# # dummies
df_por = pd.get_dummies(data=df_por, columns=nominal)

# # StandardScaler for numeric data
df_por, scaler, mean, sd = standardScaler(df_por,numeric)

## drop columns that are not labeled and reset index
# df_por.drop(nominal,axis=1,inplace=True) **
df_por.reset_index(drop=True,inplace=True)
df_por
# Out:
#       age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    18.0     4     4           2          2         0       4         3
# 1    17.0     1     1           1          2         0       5         3
# 2    15.0     1     1           1          2         0       4         3
# 3    15.0     4     2           1          3         0       3         2
# 4    16.0     3     3           1          2         0       4         3
# ..    ...   ...   ...         ...        ...       ...     ...       ...
# 628  19.0     2     3           1          3         1       5         4
# 629  18.0     3     1           1          2         0       4         3
# 630  18.0     1     1           2          2         0       1         1
# 631  17.0     3     1           2          1         0       2         4
# 632  18.0     3     2           3          1         0       4         4
#
#      goout  Dalc  ...  activities_no  activities_yes  nursery_no  nursery_yes  \
# ...

# %% [markdown]
# ## 7.1.2 Re-check correlation between G3(target) and features

# %%
plt.figure(figsize=(5,10))
ax = sns.heatmap(df_por.corr()[['G3']].sort_values(by='G3',ascending=False),annot=True,cmap='YlGnBu')
ax.set(title='Correlation between G3 and Features-Portuguese data')
plt.show()

# %% [markdown]
# ## 7.2 Model building
# - Note that: In portuguese dataframe, there are only 633 samples. Therefore, K-Fold cross validation is needed
#     - 133 samples for test set
#     - 500 samples for training and 10 folds cross validation
#
# - 7.2.1 Modeling Building by each algorithms
#     - 1.) Decision Tree
#     - 2.) RandomForestClassifier
#     - 3.) Support Vector Machine
#     - 4.) GaussianNB
# - 7.2.2 Select model and test with unseen data

# %% [markdown]
# ### 7.2.1 Modeling Building by each algorithms

# %%
df_por = df_por.sample(frac=1).reset_index(drop=True) # shuffle data
n_training_size = 500
train = df_por.iloc[:n_training_size,:]
test = df_por.iloc[n_training_size+1:,:]

X_test = test.drop(['G3'],axis=1)
y_test = test['G3']

target = ['G3']
features = df.drop(target,axis=1).columns

k_folds = 10
models = [DecisionTreeClassifier(), 
          RandomForestClassifier(),
          SVC(kernel='rbf'),
          GaussianNB()]   # Model instantiation
model_names = ['DecisionTree','RandomForest','SupportVectorMachine','NaiveBayes']
model_acc_score = dict()

for i,model in enumerate(models):
    train = df_por.iloc[:n_training_size,:]
    acc_score = list()
    
    acc_score_train = list()
    
    for k in range(k_folds):
        sample_val = train.shape[0]//k_folds
        validation = train[sample_val*k:(k+1)*sample_val]
        # x_val and y_val
        X_val = validation[features]
        y_val = validation[target]
        valid_index = validation.index

        # train set
        train_index = [i for i in range(0,train.shape[0]) if i not in valid_index]
        train_Xy = train.iloc[train_index]
        X_train = train_Xy[features]
        y_train = train_Xy[target]
        
        # fit and predict model
        model.fit(X_train,y_train)
        y_pred = model.predict(X_val)
        y_pred_adj = prediction_adjusted(y_val,y_pred)
        acc_score.append(accuracy_score(y_val,y_pred_adj))
       
    model_acc_score[model_names[i]] = acc_score

df_por_acc_score = pd.DataFrame(model_acc_score,index=['Round'+str(i+1) for i in range(k_folds)])
print('Mean Accuracy - Summary of {} Folds Cross Validation'.format(k_folds))
print('_______________________')
print(df_por_acc_score.mean())
print(df_por_acc_score)

plot_model_performance(df_por_acc_score)
# Out:
# Mean Accuracy - Summary of 10 Folds Cross Validation
# _______________________
# DecisionTree            0.582
# RandomForest            0.692
# SupportVectorMachine    0.696
# NaiveBayes              0.350
# dtype: float64
#          DecisionTree  RandomForest  SupportVectorMachine  NaiveBayes
# Round1           0.60          0.74                  0.72        0.28
# Round2           0.50          0.62                  0.66        0.44
# Round3           0.56          0.78                  0.74        0.16
# Round4           0.54          0.60                  0.66        0.50
# Round5           0.64          0.74                  0.74        0.36
# Round6           0.66          0.64                  0.66        0.28
# Round7           0.54          0.72                  0.66        0.42
# Round8           0.56          0.64                  0.68        0.34
# Round9           0.68          0.78                  0.72        0.38
# ...

# %% [markdown]
# ### 7.2.2 Select model and test with unseen data
# By considering models' performance (accuracy metrics), support vector machine model and random forest classifier models tend to offer the most promising result because these two model provide highest accuracy levels. Therefore, support vector machine and random forest are selected to test with unseen data. Also these two models will be taken to tuning process later so that we can make the final decision that which model is better.

# %% [markdown]
# ## 7.3 Model Evaluation
# - Testing with unseen data
# - Metrics: Accuracy Score, Confusion Matrix, Classification Report

# %% [markdown]
# ### 7.3.1 Test SVC model with unseen data - Portuguese

# %%
train = df_por.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
model = SVC()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("SVC Performance Evaluation: Tesing with unseen data")
print('')
print('Y-True:',np.array(y_test).ravel())
print('')
print('Y-Predict',y_pred)
print('')
print('Y-Predict-Adjusted:',y_pred_adj)
print('')
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
# Out:
# SVC Performance Evaluation: Tesing with unseen data
#
# Y-True: [15 12 10 12  9 14 11 12 12 10 11  8 13 12 14  8 18 13 15 13 12 11 16  8
#  11 11 12 11 10  7 10 13 13 12 15 18 10 14 16 13 11 12 10 16 16  9 14 10
#  15 14 13 14 11 16 13 11 11 17 10 11 15 12 14 16 12 16 12 17 13  8 17  7
#  17  8  7 12 10 13 10 13 15 16 11  7 11 15 11 13 13 12 11  9 13  8 10  9
#  15 14 12 11 11 18  8 11  9 13 10 17 11 16 13 16 16 17 14 15 15 10  8 10
#  10 15 10 10 11  7 10 15 11 14 10 13]
#
# Y-Predict [11 13 11 11 11 13 13 13 13 11 11 11 13 13 11 11 11 13 13 11 11 11 13 10
#  13 11 13 13 11 11 11 11 13 13 10 13 11 11 11 13 11 11 13 13 11 11 11 11
#  13 13 11 13 11 13 13 11 10 11 11 13 11 13 11 13 11 11 11 13 11 11 13 11
#  13 11 11 11 10 11 11 13 11 13 11 11 11 13 13 11 13 13 11 13 11 11 11 11
#  11 11 11 11 13 11 11 13 11 11 11 11 11 13 13 11 11 10 13 13 13 11 11 11
#  13 13 11 11 13 11 13 11 11 11 11 13]
#
# ...

# %% [markdown]
# ### 7.3.2 Test RandomForest model with unseen data - Portuguese

# %%
train = df_por.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]
model = RandomForestClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("Random Forest Classifier Performance Evaluation: Tesing with unseen data")
print('')
print('Y-True:',np.array(y_test).ravel())
print('')
print('Y-Predict',y_pred)
print('')
print('Y-Predict-Adjusted:',y_pred_adj)
print('')
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
# Out:
# Random Forest Classifier Performance Evaluation: Tesing with unseen data
#
# Y-True: [15 12 10 12  9 14 11 12 12 10 11  8 13 12 14  8 18 13 15 13 12 11 16  8
#  11 11 12 11 10  7 10 13 13 12 15 18 10 14 16 13 11 12 10 16 16  9 14 10
#  15 14 13 14 11 16 13 11 11 17 10 11 15 12 14 16 12 16 12 17 13  8 17  7
#  17  8  7 12 10 13 10 13 15 16 11  7 11 15 11 13 13 12 11  9 13  8 10  9
#  15 14 12 11 11 18  8 11  9 13 10 17 11 16 13 16 16 17 14 15 15 10  8 10
#  10 15 10 10 11  7 10 15 11 14 10 13]
#
# Y-Predict [12 13 11 13 12 13 11 13 13 10 13  8 13 14 11 10 10 12 12 11 14 13 13 10
#  13 13 13 10 11 10 10 11 15 12 10 13 13 11 13 13 11 13 13 17 12 11 14 10
#  13 13 11 14 10 14 11 10 14 13 11 13 12 10 13 13 10 11 11 10 11 10 14 10
#  11 11  8 11  9 15 10 12 12 11 11 11 10 16 13 10 11 13 12 11 13 10 11 10
#  11 14 11 11 13 11 10 13 11  9  8 10 10 11 11 10 11 15 13 13 15 12 11 13
#  12 11 10 10 10 10 13 11 11 13 10 14]
#
# ...

# %% [markdown]
# ## 7.4 Model Improvement
# - 7.4.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model
#     - Re-train SVC model and evaluate performance - name: model_svc_por
# - 7.4.2 RandomoizeSearchCV for tuning the model
#     - Re-train randomforest model and evaluate - name: model_RNF_por

# %% [markdown]
# ###  7.4.1 Using RandomizedSearchCV to find best hyperparameters for the SVC model
# - Re-train SVC model and evaluate performance - name: model_svc_por

# %%
# for collecting model and accuracy for portuguese data
model_acc_por = dict()

# %%
from sklearn.model_selection import RandomizedSearchCV
model = SVC()
param_dict_SVC = {'C':[0.1,1,10,50],
             'kernel':['linear','rbf','poly','sigmoid'],
             'gamma':[10,1,0.5,0.1],
             'shrinking':[True,False],
             'coef0' :[0.0,0.1,0.5]}
param_dict_svc= RandomizedSearchCV(model, param_dict_SVC, cv=10,n_iter = 100,scoring='accuracy',verbose=1)
param_dict_svc.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# RandomizedSearchCV(cv=10, estimator=SVC(), n_iter=100,
#                    param_distributions={'C': [0.1, 1, 10, 50],
#                                         'coef0': [0.0, 0.1, 0.5],
#                                         'gamma': [10, 1, 0.5, 0.1],
#                                         'kernel': ['linear', 'rbf', 'poly',
#                                                    'sigmoid'],
#                                         'shrinking': [True, False]},
#                    scoring='accuracy', verbose=1)

# %%
param_dict_svc.best_params_
# Out:
# {'shrinking': False, 'kernel': 'rbf', 'gamma': 0.1, 'coef0': 0.1, 'C': 1}

# %%
train = df_por.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]

model_svc_por = SVC(C=param_dict_svc.best_params_['C'],
            coef0 = param_dict_svc.best_params_['coef0'], 
            gamma =param_dict_svc.best_params_['gamma'], 
            kernel=param_dict_svc.best_params_['kernel'],
            shrinking=param_dict_svc.best_params_['shrinking'])
model_svc_por.fit(X_train,y_train)
y_pred = model_svc_por.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("SVC-After tuning: Tesing with unseen data")
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
model_acc_por[model_svc_por] = accuracy_score(y_test,y_pred_adj)*100
# Out:
# SVC-After tuning: Tesing with unseen data
# Accuracy_score 65.15%
#
#               precision    recall  f1-score   support
#
#            7       0.00      0.00      0.00         5
#            8       1.00      0.38      0.55         8
#            9       1.00      0.80      0.89         5
#           10       0.66      1.00      0.79        19
#           11       0.42      1.00      0.59        21
#           12       1.00      1.00      1.00        15
#           13       0.65      0.76      0.70        17
#           14       1.00      0.30      0.46        10
#           15       1.00      0.50      0.67        12
#           16       1.00      0.18      0.31        11
#           17       0.00      0.00      0.00         6
#           18       0.00      0.00      0.00         3
#
#     accuracy                           0.65       132
#    macro avg       0.64      0.49      0.50       132
# weighted avg       0.71      0.65      0.60       132

# %% [markdown]
# ## 7.4.2 RandomizeSearchCV for tuning the RandomForest model
# - Re-train randomforest model and evaluate - name: model_RNF_por

# %%
from sklearn.model_selection import RandomizedSearchCV
model = RandomForestClassifier()

estimators = [100,300,500,800,1200]
max_features = ['auto','log2']
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 20]
min_samples_leaf = [1, 2, 5, 10]

param_dict_RnF = dict(n_estimators = estimators, max_depth = max_depth,  
              min_samples_split = min_samples_split, 
             min_samples_leaf = min_samples_leaf)

param_dict= RandomizedSearchCV(model, param_dict_RnF, cv=10,n_iter = 100,scoring='accuracy',verbose=1)
param_dict.fit(X_train,y_train)
# Out:
# Fitting 10 folds for each of 100 candidates, totalling 1000 fits
# RandomizedSearchCV(cv=10, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'max_depth': [5, 8, 15, 25, 30],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15, 20],
#                                         'n_estimators': [100, 300, 500, 800,
#                                                          1200]},
#                    scoring='accuracy', verbose=1)

# %%
param_dict.best_params_
# Out:
# {'n_estimators': 100,
#  'min_samples_split': 20,
#  'min_samples_leaf': 10,
#  'max_depth': 5}

# %%
train = df_por.iloc[:n_training_size,:]
X_train = train[features]
y_train = train[target]

model_RNF_por = RandomForestClassifier(n_estimators= param_dict.best_params_['n_estimators'],
                               max_features = 'auto',
                               max_depth=  param_dict.best_params_['max_depth'],
                               min_samples_split=param_dict.best_params_['min_samples_split'], 
                               min_samples_leaf=param_dict.best_params_['min_samples_leaf'])
model_RNF_por.fit(X_train,y_train)
y_pred = model_RNF_por.predict(X_test)
y_pred_adj = prediction_adjusted(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred_adj)
print("RandomForest-After GridSearchCV: Tesing with unseen data")
print('Accuracy_score {:.2f}%'.format(accuracy_score(y_test,y_pred_adj)*100))
print('')
print(classification_report(y_test,y_pred_adj))
plot_confusion_matrix(y_test,y_pred_adj)
model_acc_por[model_RNF_por] = accuracy_score(y_test,y_pred_adj)*100
# Out:
# RandomForest-After GridSearchCV: Tesing with unseen data
# Accuracy_score 67.42%
#
#               precision    recall  f1-score   support
#
#            7       0.00      0.00      0.00         5
#            8       1.00      0.75      0.86         8
#            9       1.00      0.60      0.75         5
#           10       0.67      0.95      0.78        19
#           11       0.50      1.00      0.67        21
#           12       0.94      1.00      0.97        15
#           13       0.56      0.88      0.68        17
#           14       1.00      0.50      0.67        10
#           15       1.00      0.42      0.59        12
#           16       1.00      0.09      0.17        11
#           17       0.00      0.00      0.00         6
#           18       0.00      0.00      0.00         3
#
#     accuracy                           0.67       132
#    macro avg       0.64      0.52      0.51       132
# weighted avg       0.70      0.67      0.61       132

# %% [markdown]
# Therefore, select the model that give higest accuracy

# %%
model_acc_por
# Out:
# {SVC(C=1, coef0=0.1, gamma=0.1, shrinking=False): 65.15151515151516,
#  RandomForestClassifier(max_depth=5, min_samples_leaf=10, min_samples_split=20): 67.42424242424242}

# %% [markdown]
# # 8. Conclusion
# - Select the models that provide the highest accuracy for both math-score and portuguese score

# %%
print('For Prediction Math Score')
for key,value in model_acc_math.items():
    print('-',key,'----> accuracy :',value)
# Out:
# For Prediction Math Score
# - SVC(C=1, gamma=0.1, shrinking=False) ----> accuracy : 55.35714285714286
# - RandomForestClassifier(max_depth=8, min_samples_leaf=10, n_estimators=300) ----> accuracy : 57.14285714285714
# - RandomForestClassifier(max_depth=5, min_samples_leaf=10, min_samples_split=10,
#                        n_estimators=300) ----> accuracy : 53.57142857142857

# %%
print('For Prediction Portuguese Score')
for key,value in model_acc_por.items():
    print('-',key,'----> accuracy :',value)
# Out:
# For Prediction Portuguese Score
# - SVC(C=1, coef0=0.1, gamma=0.1, shrinking=False) ----> accuracy : 65.15151515151516
# - RandomForestClassifier(max_depth=5, min_samples_leaf=10, min_samples_split=20) ----> accuracy : 67.42424242424242
